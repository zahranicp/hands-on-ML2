# %% [markdown]
# ### Nama : Zahrani Cahya Priesa
# ### NIM : 1103223074
# ### Mata Kuliah : Machine Learning

# %%
# ============================================
# Import Libraries & Setup
# ============================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# TensorFlow & Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model

# Set style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Set random seeds
np.random.seed(42)
tf.random.set_seed(42)

print("=" * 60)
print("FUNCTIONAL API & SUBCLASSING")
print("=" * 60)
print(f"TensorFlow version: {tf.__version__}")
print("\n✅ Libraries imported successfully!")
# Out:
# ============================================================
# FUNCTIONAL API & SUBCLASSING
# ============================================================
# TensorFlow version: 2.18.0
#
# ✅ Libraries imported successfully!

# %%
# ============================================
# Load & Prepare Housing Data
# ============================================

print("\n" + "=" * 60)
print("DATA PREPARATION")
print("=" * 60)

# Create synthetic housing data (same as Notebook 2)
np.random.seed(42)
n_samples = 20640

# Generate features
X_housing = np.random.randn(n_samples, 8)

# Generate target
y_housing = (
    3.0 * X_housing[:, 0] + 
    -0.5 * X_housing[:, 1] + 
    1.5 * X_housing[:, 2] + 
    -1.0 * X_housing[:, 3] + 
    0.3 * X_housing[:, 4] + 
    np.random.randn(n_samples) * 0.5
)
y_housing = (y_housing - y_housing.min()) / (y_housing.max() - y_housing.min()) * 4 + 0.5

# Split data
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train_full, X_test, y_train_full, y_test = train_test_split(
    X_housing, y_housing, test_size=0.2, random_state=42
)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, test_size=0.2, random_state=42
)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

print(f"\nData Loaded:")
print(f"  Training: {X_train_scaled.shape[0]:,} samples")
print(f"  Validation: {X_valid_scaled.shape[0]:,} samples")
print(f"  Test: {X_test_scaled.shape[0]:,} samples")
print(f"  Features: {X_train_scaled.shape[1]}")

print("\n✅ Data preparation completed!")
# Out:
# ============================================================
# DATA PREPARATION
# ============================================================
#
# Data Loaded:
#   Training: 13,209 samples
#   Validation: 3,303 samples
#   Test: 4,128 samples
#   Features: 8
#
# ✅ Data preparation completed!

# %%
# ============================================
# Sequential API - Quick Recap
# ============================================

print("\n" + "=" * 60)
print("API COMPARISON: SEQUENTIAL vs FUNCTIONAL vs SUBCLASSING")
print("=" * 60)

print("\n1️ SEQUENTIAL API")
print("-" * 60)
print("✅ Pros:")
print("  • Simple and intuitive")
print("  • Easy to use for beginners")
print("  • Linear stack of layers")
print("\n❌ Cons:")
print("  • Only for sequential models")
print("  • Cannot handle multiple inputs/outputs")
print("  • No shared layers or complex topologies")

# Example Sequential Model
model_sequential = keras.Sequential([
    layers.Dense(30, activation="relu", input_shape=[8]),
    layers.Dense(30, activation="relu"),
    layers.Dense(1)
])

print("\nSequential Model:")
model_sequential.summary()

print("\n✅ Sequential API demonstrated!")
# Out:
# ============================================================
# API COMPARISON: SEQUENTIAL vs FUNCTIONAL vs SUBCLASSING
# ============================================================
#
# 1️ SEQUENTIAL API
# ------------------------------------------------------------
# ✅ Pros:
#   • Simple and intuitive
#   • Easy to use for beginners
#   • Linear stack of layers
#
# ❌ Cons:
#   • Only for sequential models
#   • Cannot handle multiple inputs/outputs
#   • No shared layers or complex topologies
#
# Sequential Model:
# C:\Users\User\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 30)             │           270 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,231 (4.81 KB)
#  Trainable params: 1,231 (4.81 KB)
#  Non-trainable params: 0 (0.00 B)
# ✅ Sequential API demonstrated!

# %%
# ============================================
# Functional API - Basic Example
# ============================================

print("\n" + "=" * 60)
print("FUNCTIONAL API - BASIC EXAMPLE")
print("=" * 60)

print("\n2️ FUNCTIONAL API")
print("-" * 60)
print("✅ Pros:")
print("  • Flexible architecture")
print("  • Multiple inputs/outputs")
print("  • Shared layers")
print("  • Complex topologies (DAG)")
print("\n❌ Cons:")
print("  • Slightly more verbose")
print("  • Requires understanding of data flow")

# Define input
input_layer = layers.Input(shape=[8], name="input")

# Define hidden layers
hidden1 = layers.Dense(30, activation="relu", name="hidden1")(input_layer)
hidden2 = layers.Dense(30, activation="relu", name="hidden2")(hidden1)

# Define output
output_layer = layers.Dense(1, name="output")(hidden2)

# Create model
model_functional = Model(inputs=input_layer, outputs=output_layer, name="functional_model")

print("\nFunctional Model (Same Architecture as Sequential):")
model_functional.summary()

print("\nKey Differences:")
print("  • Sequential: model = Sequential([layers...])")
print("  • Functional: define inputs → connect layers → create Model()")

print("\n✅ Functional API demonstrated!")
# Out:
# ============================================================
# FUNCTIONAL API - BASIC EXAMPLE
# ============================================================
#
# 2️ FUNCTIONAL API
# ------------------------------------------------------------
# ✅ Pros:
#   • Flexible architecture
#   • Multiple inputs/outputs
#   • Shared layers
#   • Complex topologies (DAG)
#
# ❌ Cons:
#   • Slightly more verbose
#   • Requires understanding of data flow
#
# Functional Model (Same Architecture as Sequential):
# Model: "functional_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden1 (Dense)                 │ (None, 30)             │           270 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,231 (4.81 KB)
#  Trainable params: 1,231 (4.81 KB)
#  Non-trainable params: 0 (0.00 B)
# Key Differences:
#   • Sequential: model = Sequential([layers...])
#   • Functional: define inputs → connect layers → create Model()
#
# ✅ Functional API demonstrated!

# %%
# ============================================
# Wide & Deep Network
# ============================================

print("\n" + "=" * 60)
print("WIDE & DEEP NETWORK ARCHITECTURE")
print("=" * 60)

print("\nWide & Deep Concept:")
print("-" * 60)
print("WIDE PATH:")
print("  • Short path from input to output")
print("  • Memorizes patterns directly")
print("  • Good for simple, sparse features")
print("\nDEEP PATH:")
print("  • Multiple hidden layers")
print("  • Learns complex representations")
print("  • Good for generalization")

# Prepare data splits
X_train_A = X_train_scaled[:, :5]  # First 5 features for wide
X_train_B = X_train_scaled[:, 2:]  # Last 6 features for deep (with overlap)
X_valid_A = X_valid_scaled[:, :5]
X_valid_B = X_valid_scaled[:, 2:]
X_test_A = X_test_scaled[:, :5]
X_test_B = X_test_scaled[:, 2:]

# Define inputs
input_A = layers.Input(shape=[5], name="wide_input")
input_B = layers.Input(shape=[6], name="deep_input")

# DEEP PATH
hidden1 = layers.Dense(30, activation="relu", name="deep_hidden1")(input_B)
hidden2 = layers.Dense(30, activation="relu", name="deep_hidden2")(hidden1)

# CONCATENATE wide + deep
concat = layers.Concatenate()([input_A, hidden2])

# Output layer
output = layers.Dense(1, name="output")(concat)

# Create model
model_wide_deep = Model(inputs=[input_A, input_B], outputs=output, name="wide_deep_model")

print("\nWide & Deep Model Architecture:")
model_wide_deep.summary()

# Visualize architecture
print("\n Architecture Diagram:")
print("-" * 60)
print("input_A (5) ─────────────┐")
print("                          │")
print("                          ├──→ Concatenate ──→ Output")
print("                          │")
print("input_B (6) ──→ Dense ───→│")
print("               ↓")
print("              Dense")

print("\n✅ Wide & Deep model created!")
# Out:
# ============================================================
# WIDE & DEEP NETWORK ARCHITECTURE
# ============================================================
#
# Wide & Deep Concept:
# ------------------------------------------------------------
# WIDE PATH:
#   • Short path from input to output
#   • Memorizes patterns directly
#   • Good for simple, sparse features
#
# DEEP PATH:
#   • Multiple hidden layers
#   • Learns complex representations
#   • Good for generalization
#
# Wide & Deep Model Architecture:
# Model: "wide_deep_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ deep_input          │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deep_hidden1        │ (None, 30)        │        210 │ deep_input[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ wide_input          │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deep_hidden2        │ (None, 30)        │        930 │ deep_hidden1[0][… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 35)        │          0 │ wide_input[0][0], │
# │ (Concatenate)       │                   │            │ deep_hidden2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │         36 │ concatenate_2[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,176 (4.59 KB)
#  Trainable params: 1,176 (4.59 KB)
#  Non-trainable params: 0 (0.00 B)
#  Architecture Diagram:
# ------------------------------------------------------------
# input_A (5) ─────────────┐
#                           │
#                           ├──→ Concatenate ──→ Output
#                           │
# input_B (6) ──→ Dense ───→│
#                ↓
#               Dense
#
# ✅ Wide & Deep model created!

# %%
# ============================================
# Multiple Outputs Model
# ============================================

print("\n" + "=" * 60)
print("MULTIPLE OUTPUTS MODEL")
print("=" * 60)

print("\n🎯 Use Case:")
print("  • Predicting BOTH house price AND category")
print("  • One model, two tasks (multi-task learning)")

# Create synthetic categories (0: cheap, 1: medium, 2: expensive)
y_train_cat = np.digitize(y_train, bins=[1.5, 3.0])
y_valid_cat = np.digitize(y_valid, bins=[1.5, 3.0])
y_test_cat = np.digitize(y_test, bins=[1.5, 3.0])

# Define input
input_layer = layers.Input(shape=[8], name="input")

# Shared hidden layers
hidden1 = layers.Dense(30, activation="relu", name="hidden1")(input_layer)
hidden2 = layers.Dense(30, activation="relu", name="hidden2")(hidden1)

# OUTPUT 1: Regression (price)
output_price = layers.Dense(1, name="price")(hidden2)

# OUTPUT 2: Classification (category)
output_category = layers.Dense(3, activation="softmax", name="category")(hidden2)

# Create model with MULTIPLE outputs
model_multi_output = Model(
    inputs=input_layer,
    outputs=[output_price, output_category],
    name="multi_output_model"
)

print("\nMulti-Output Model:")
model_multi_output.summary()

print("\nArchitecture:")
print("-" * 60)
print("Input (8)")
print("  ↓")
print("Dense(30) → Dense(30)")
print("  ├──→ Dense(1) → Price (regression)")
print("  └──→ Dense(3, softmax) → Category (classification)")

print("\n✅ Multi-output model created!")
# Out:
# ============================================================
# MULTIPLE OUTPUTS MODEL
# ============================================================
#
# 🎯 Use Case:
#   • Predicting BOTH house price AND category
#   • One model, two tasks (multi-task learning)
#
# Multi-Output Model:
# Model: "multi_output_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 8)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hidden1 (Dense)     │ (None, 30)        │        270 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hidden2 (Dense)     │ (None, 30)        │        930 │ hidden1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ price (Dense)       │ (None, 1)         │         31 │ hidden2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ category (Dense)    │ (None, 3)         │         93 │ hidden2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,324 (5.17 KB)
#  Trainable params: 1,324 (5.17 KB)
#  Non-trainable params: 0 (0.00 B)
# Architecture:
# ------------------------------------------------------------
# Input (8)
#   ↓
# Dense(30) → Dense(30)
#   ├──→ Dense(1) → Price (regression)
#   └──→ Dense(3, softmax) → Category (classification)
#
# ✅ Multi-output model created!

# %%
# ============================================
# Training Multi-Output Model
# ============================================

print("\n" + "=" * 60)
print("TRAINING MULTI-OUTPUT MODEL")
print("=" * 60)

# Compile with DIFFERENT losses for each output
model_multi_output.compile(
    loss={
        "price": "mse",
        "category": "sparse_categorical_crossentropy"
    },
    optimizer="sgd",
    metrics={
        "price": ["mae"],
        "category": ["accuracy"]
    }
)

print("Compilation Settings:")
print("  Price output: MSE loss + MAE metric")
print("  Category output: Sparse CE loss + Accuracy metric")

# Train
print("\nTraining started...")
history_mo = model_multi_output.fit(
    X_train_scaled,
    {"price": y_train, "category": y_train_cat},
    epochs=20,
    validation_data=(X_valid_scaled, {"price": y_valid, "category": y_valid_cat}),
    verbose=1
)

print("\n✅ Multi-output training completed!")

# Evaluate
results = model_multi_output.evaluate(
    X_test_scaled,
    {"price": y_test, "category": y_test_cat},
    verbose=0
)

print(f"\nMulti-Output Test Performance:")
print(f"  Price MSE: {results[1]:.4f}")
print(f"  Price MAE: {results[3]:.4f}")
print(f"  Category Accuracy: {results[4]*100:.2f}%")
# Out:
# ============================================================
# TRAINING MULTI-OUTPUT MODEL
# ============================================================
# Compilation Settings:
#   Price output: MSE loss + MAE metric
#   Category output: Sparse CE loss + Accuracy metric
#
# Training started...
# Epoch 1/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - category_accuracy: 0.7001 - category_loss: 0.7535 - loss: 1.3712 - price_loss: 0.6177 - price_mae: 0.5158 - val_category_accuracy: 0.8235 - val_category_loss: 0.4888 - val_loss: 0.5390 - val_price_loss: 0.0497 - val_price_mae: 0.1789
# Epoch 2/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.8372 - category_loss: 0.4544 - loss: 0.4953 - price_loss: 0.0409 - price_mae: 0.1596 - val_category_accuracy: 0.8907 - val_category_loss: 0.3360 - val_loss: 0.3627 - val_price_loss: 0.0260 - val_price_mae: 0.1274
# Epoch 3/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.8996 - category_loss: 0.3104 - loss: 0.3332 - price_loss: 0.0228 - price_mae: 0.1180 - val_category_accuracy: 0.9146 - val_category_loss: 0.2351 - val_loss: 0.2534 - val_price_loss: 0.0177 - val_price_mae: 0.1045
# Epoch 4/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9226 - category_loss: 0.2203 - loss: 0.2360 - price_loss: 0.0158 - price_mae: 0.0984 - val_category_accuracy: 0.9319 - val_category_loss: 0.1832 - val_loss: 0.1980 - val_price_loss: 0.0143 - val_price_mae: 0.0941
# Epoch 5/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9407 - category_loss: 0.1737 - loss: 0.1865 - price_loss: 0.0128 - price_mae: 0.0891 - val_category_accuracy: 0.9404 - val_category_loss: 0.1553 - val_loss: 0.1683 - val_price_loss: 0.0126 - val_price_mae: 0.0884
# Epoch 6/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9480 - category_loss: 0.1481 - loss: 0.1594 - price_loss: 0.0113 - price_mae: 0.0839 - val_category_accuracy: 0.9479 - val_category_loss: 0.1387 - val_loss: 0.1506 - val_price_loss: 0.0115 - val_price_mae: 0.0845
# Epoch 7/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9519 - category_loss: 0.1324 - loss: 0.1428 - price_loss: 0.0104 - price_mae: 0.0805 - val_category_accuracy: 0.9503 - val_category_loss: 0.1278 - val_loss: 0.1388 - val_price_loss: 0.0107 - val_price_mae: 0.0815
# Epoch 8/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9545 - category_loss: 0.1217 - loss: 0.1315 - price_loss: 0.0098 - price_mae: 0.0781 - val_category_accuracy: 0.9513 - val_category_loss: 0.1200 - val_loss: 0.1305 - val_price_loss: 0.0101 - val_price_mae: 0.0792
# Epoch 9/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9557 - category_loss: 0.1139 - loss: 0.1232 - price_loss: 0.0093 - price_mae: 0.0763 - val_category_accuracy: 0.9534 - val_category_loss: 0.1142 - val_loss: 0.1242 - val_price_loss: 0.0096 - val_price_mae: 0.0773
# Epoch 10/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9572 - category_loss: 0.1080 - loss: 0.1169 - price_loss: 0.0090 - price_mae: 0.0748 - val_category_accuracy: 0.9537 - val_category_loss: 0.1098 - val_loss: 0.1193 - val_price_loss: 0.0092 - val_price_mae: 0.0757
# Epoch 11/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9591 - category_loss: 0.1033 - loss: 0.1120 - price_loss: 0.0087 - price_mae: 0.0736 - val_category_accuracy: 0.9537 - val_category_loss: 0.1063 - val_loss: 0.1155 - val_price_loss: 0.0089 - val_price_mae: 0.0743
# Epoch 12/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9595 - category_loss: 0.0995 - loss: 0.1079 - price_loss: 0.0084 - price_mae: 0.0725 - val_category_accuracy: 0.9543 - val_category_loss: 0.1035 - val_loss: 0.1124 - val_price_loss: 0.0086 - val_price_mae: 0.0731
# Epoch 13/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9611 - category_loss: 0.0964 - loss: 0.1045 - price_loss: 0.0082 - price_mae: 0.0716 - val_category_accuracy: 0.9546 - val_category_loss: 0.1013 - val_loss: 0.1099 - val_price_loss: 0.0084 - val_price_mae: 0.0721
# Epoch 14/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9621 - category_loss: 0.0938 - loss: 0.1018 - price_loss: 0.0080 - price_mae: 0.0708 - val_category_accuracy: 0.9549 - val_category_loss: 0.0995 - val_loss: 0.1079 - val_price_loss: 0.0082 - val_price_mae: 0.0712
# Epoch 15/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - category_accuracy: 0.9631 - category_loss: 0.0917 - loss: 0.0995 - price_loss: 0.0078 - price_mae: 0.0701 - val_category_accuracy: 0.9561 - val_category_loss: 0.0979 - val_loss: 0.1061 - val_price_loss: 0.0080 - val_price_mae: 0.0705
# Epoch 16/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - category_accuracy: 0.9640 - category_loss: 0.0899 - loss: 0.0976 - price_loss: 0.0077 - price_mae: 0.0695 - val_category_accuracy: 0.9558 - val_category_loss: 0.0966 - val_loss: 0.1046 - val_price_loss: 0.0078 - val_price_mae: 0.0698
# Epoch 17/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9649 - category_loss: 0.0884 - loss: 0.0959 - price_loss: 0.0075 - price_mae: 0.0689 - val_category_accuracy: 0.9561 - val_category_loss: 0.0954 - val_loss: 0.1033 - val_price_loss: 0.0077 - val_price_mae: 0.0693
# Epoch 18/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9653 - category_loss: 0.0870 - loss: 0.0944 - price_loss: 0.0074 - price_mae: 0.0684 - val_category_accuracy: 0.9564 - val_category_loss: 0.0944 - val_loss: 0.1022 - val_price_loss: 0.0076 - val_price_mae: 0.0688
# Epoch 19/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9657 - category_loss: 0.0858 - loss: 0.0931 - price_loss: 0.0073 - price_mae: 0.0680 - val_category_accuracy: 0.9564 - val_category_loss: 0.0935 - val_loss: 0.1012 - val_price_loss: 0.0075 - val_price_mae: 0.0683
# Epoch 20/20
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - category_accuracy: 0.9658 - category_loss: 0.0847 - loss: 0.0920 - price_loss: 0.0072 - price_mae: 0.0676 - val_category_accuracy: 0.9567 - val_category_loss: 0.0927 - val_loss: 0.1003 - val_price_loss: 0.0074 - val_price_mae: 0.0679
#
# ✅ Multi-output training completed!
#
# Multi-Output Test Performance:
#   Price MSE: 0.0072
#   Price MAE: 0.9610
#   Category Accuracy: 6.70%

# %%
# ============================================
# Subclassing API - Custom Model
# ============================================

print("\n" + "=" * 60)
print("SUBCLASSING API - DYNAMIC MODELS")
print("=" * 60)

print("\n3️ SUBCLASSING API")
print("-" * 60)
print("✅ Pros:")
print("  • Maximum flexibility")
print("  • Dynamic behavior (if/else, loops)")
print("  • Custom training loops")
print("  • Research-oriented")
print("\n❌ Cons:")
print("  • Most verbose")
print("  • Harder to debug")
print("  • No automatic model.summary()")

# Define custom model class
class WideAndDeepModel(keras.Model):
    def __init__(self, units=30, activation="relu", **kwargs):
        super().__init__(**kwargs)
        # Define layers in __init__
        self.hidden1 = layers.Dense(units, activation=activation, name="hidden1")
        self.hidden2 = layers.Dense(units, activation=activation, name="hidden2")
        self.main_output = layers.Dense(1, name="main_output")
        self.aux_output = layers.Dense(1, name="aux_output")
    
    def call(self, inputs):
        # Define forward pass in call()
        input_A, input_B = inputs
        hidden1 = self.hidden1(input_B)
        hidden2 = self.hidden2(hidden1)
        concat = layers.concatenate([input_A, hidden2])
        main_output = self.main_output(concat)
        aux_output = self.aux_output(hidden2)
        return main_output, aux_output

# Instantiate custom model
model_subclass = WideAndDeepModel(units=30)

print("\nCustom Subclassed Model Created!")
print("  • Class: WideAndDeepModel")
print("  • Inherits from: keras.Model")
print("  • Custom __init__: Define layers")
print("  • Custom call(): Define forward pass")

print("\nNOTE: model.summary() not available automatically!")
print("   Need to build the model first with input shape.")

# Build model
model_subclass.build(input_shape=[(None, 5), (None, 6)])

print("\n✅ Subclassing model created!")
# Out:
# ============================================================
# SUBCLASSING API - DYNAMIC MODELS
# ============================================================
#
# 3️ SUBCLASSING API
# ------------------------------------------------------------
# ✅ Pros:
#   • Maximum flexibility
#   • Dynamic behavior (if/else, loops)
#   • Custom training loops
#   • Research-oriented
#
# ❌ Cons:
#   • Most verbose
#   • Harder to debug
#   • No automatic model.summary()
#
# Custom Subclassed Model Created!
#   • Class: WideAndDeepModel
#   • Inherits from: keras.Model
#   • Custom __init__: Define layers
#   • Custom call(): Define forward pass
#
# NOTE: model.summary() not available automatically!
#    Need to build the model first with input shape.
#
# ✅ Subclassing model created!
# C:\Users\User\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\layer.py:393: UserWarning: `build()` was called on layer 'wide_and_deep_model_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(

# %%
# ============================================
# Training Subclassed Model
# ============================================

import numpy as np

# Ensure shapes
X_train_A = np.asarray(X_train_A)
X_train_B = np.asarray(X_train_B)
X_valid_A = np.asarray(X_valid_A)
X_valid_B = np.asarray(X_valid_B)
X_test_A  = np.asarray(X_test_A)
X_test_B  = np.asarray(X_test_B)

y_train = np.asarray(y_train).reshape(-1, 1)
y_valid = np.asarray(y_valid).reshape(-1, 1)
y_test  = np.asarray(y_test).reshape(-1, 1)

# Fix cardinality
n_train = y_train.shape[0]
n_valid = y_valid.shape[0]
n_test  = y_test.shape[0]

X_train_A = X_train_A[:n_train]
X_train_B = X_train_B[:n_train]

X_valid_A = X_valid_A[:n_valid]
X_valid_B = X_valid_B[:n_valid]

X_test_A  = X_test_A[:n_test]
X_test_B  = X_test_B[:n_test]

print("\n" + "=" * 60)
print("TRAINING SUBCLASSED MODEL")
print("=" * 60)

# Compile
model_subclass.compile(
    loss="mse",
    optimizer="sgd",
    metrics=["mae", "mae"]
)

print("Model compiled!")

# Train
print("\nTraining started...")
history_subclass = model_subclass.fit(
    [X_train_A, X_train_B],
    [y_train, y_train],
    epochs=20,
    validation_data=(
        [X_valid_A, X_valid_B],
        [y_valid, y_valid]
    ),
    verbose=0
)

print("✅ Training completed!")

# Evaluate
results = model_subclass.evaluate(
    [X_test_A, X_test_B],
    [y_test, y_test],
    verbose=0
)

print("\nSubclassed Model Performance:")
print(f"  Total Loss : {results[0]:.4f}")
print(f"  Main Loss  : {results[1]:.4f}")
print(f"  Aux Loss   : {results[2]:.4f}")
print(f"  Main MAE   : {results[3]:.4f}")
print(f"  Aux MAE    : {results[4]:.4f}")
# Out:
# ============================================================
# TRAINING SUBCLASSED MODEL
# ============================================================
# Model compiled!
#
# Training started...
# ✅ Training completed!
#
# Subclassed Model Performance:
#   Total Loss : 0.2956
#   Main Loss  : 0.0615
#   Aux Loss   : 0.0615
#   Main MAE   : 0.2897
#   Aux MAE    : 0.2897

# %%
# ============================================
# API Comparison Summary
# ============================================

print("\n" + "=" * 60)
print("API COMPARISON SUMMARY")
print("=" * 60)

comparison_data = {
    'Feature': [
        'Ease of Use',
        'Code Verbosity',
        'Multiple Inputs',
        'Multiple Outputs',
        'Shared Layers',
        'Dynamic Behavior',
        'model.summary()',
        'Best For'
    ],
    'Sequential': [
        '⭐⭐⭐⭐⭐',
        'Minimal',
        '❌',
        '❌',
        '❌',
        '❌',
        '✅',
        'Simple models'
    ],
    'Functional': [
        '⭐⭐⭐⭐',
        'Moderate',
        '✅',
        '✅',
        '✅',
        '❌',
        '✅',
        'Complex architectures'
    ],
    'Subclassing': [
        '⭐⭐⭐',
        'Verbose',
        '✅',
        '✅',
        '✅',
        '✅',
        '⚠️ Manual',
        'Research & custom models'
    ]
}

df_comparison = pd.DataFrame(comparison_data)

print("\n" + "=" * 90)
print(df_comparison.to_string(index=False))
print("=" * 90)

print("\n📊 DECISION GUIDE:")
print("-" * 60)
print("Use SEQUENTIAL when:")
print("  → Simple feedforward network")
print("  → Single input, single output")
print("  → Linear stack of layers")

print("\nUse FUNCTIONAL when:")
print("  → Multiple inputs/outputs")
print("  → Shared layers (e.g., Siamese networks)")
print("  → Non-sequential topology (skip connections)")

print("\nUse SUBCLASSING when:")
print("  → Need dynamic behavior (if/else, loops)")
print("  → Custom training loops")
print("  → Research & experimentation")

print("\n✅ API comparison completed!")
# Out:
# ============================================================
# API COMPARISON SUMMARY
# ============================================================
#
# ==========================================================================================
#          Feature    Sequential            Functional              Subclassing
#      Ease of Use         ⭐⭐⭐⭐⭐                  ⭐⭐⭐⭐                      ⭐⭐⭐
#   Code Verbosity       Minimal              Moderate                  Verbose
#  Multiple Inputs             ❌                     ✅                        ✅
# Multiple Outputs             ❌                     ✅                        ✅
#    Shared Layers             ❌                     ✅                        ✅
# Dynamic Behavior             ❌                     ❌                        ✅
#  model.summary()             ✅                     ✅                ⚠️ Manual
#         Best For Simple models Complex architectures Research & custom models
# ==========================================================================================
#
# 📊 DECISION GUIDE:
# ------------------------------------------------------------
# Use SEQUENTIAL when:
#   → Simple feedforward network
#   → Single input, single output
#   → Linear stack of layers
#
# Use FUNCTIONAL when:
#   → Multiple inputs/outputs
#   → Shared layers (e.g., Siamese networks)
#   → Non-sequential topology (skip connections)
#
# Use SUBCLASSING when:
#   → Need dynamic behavior (if/else, loops)
#   → Custom training loops
#   → Research & experimentation
#
# ✅ API comparison completed!

# %%
# ============================================
# Saving & Loading Models
# ============================================

print("\n" + "=" * 60)
print("SAVING & LOADING MODELS")
print("=" * 60)

# Save functional model
model_functional.save("functional_model.keras")
print("✅ Functional model saved: functional_model.keras")

# Save wide & deep model
model_wide_deep.save("wide_deep_model.keras")
print("✅ Wide & Deep model saved: wide_deep_model.keras")

# Load model
loaded_model = keras.models.load_model("functional_model.keras")
print("\n✅ Model loaded successfully!")

# Compile loaded model (IMPORTANT!)
loaded_model.compile(
    loss="mse",
    optimizer="sgd",
    metrics=["mae"]
)
print("✅ Loaded model compiled!")

# Verify loaded model
test_loss, test_mae = loaded_model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"\nLoaded Model Performance:")
print(f"  Test Loss (MSE): {test_loss:.4f}")
print(f"  Test MAE: {test_mae:.4f}")

print("\nSaving Formats:")
print("-" * 60)
print("1. KERAS FORMAT (.keras) - RECOMMENDED ⭐")
print("   • Native Keras format")
print("   • Saves architecture + weights + optimizer state")
print("   • Usage: model.save('model.keras')")

print("\n2. H5 FORMAT (.h5) - LEGACY")
print("   • HDF5 format")
print("   • Larger file size")
print("   • Usage: model.save('model.h5')")

print("\n3. SAVEDMODEL FORMAT (directory)")
print("   • TensorFlow SavedModel")
print("   • For TensorFlow Serving")
print("   • Usage: model.save('my_model')")

print("\n⚠️ IMPORTANT NOTE:")
print("  When loading models, you may need to re-compile them")
print("  if optimizer state is not preserved!")

print("\n✅ Model saving demonstrated!")
# Out:
# ============================================================
# SAVING & LOADING MODELS
# ============================================================
# ✅ Functional model saved: functional_model.keras
# ✅ Wide & Deep model saved: wide_deep_model.keras
#
# ✅ Model loaded successfully!
# ✅ Loaded model compiled!
#
# Loaded Model Performance:
#   Test Loss (MSE): 7.4986
#   Test MAE: 2.6914
#
# Saving Formats:
# ------------------------------------------------------------
# 1. KERAS FORMAT (.keras) - RECOMMENDED ⭐
#    • Native Keras format
#    • Saves architecture + weights + optimizer state
#    • Usage: model.save('model.keras')
#
# 2. H5 FORMAT (.h5) - LEGACY
#    • HDF5 format
#    • Larger file size
#    • Usage: model.save('model.h5')
#
# 3. SAVEDMODEL FORMAT (directory)
#    • TensorFlow SavedModel
#    • For TensorFlow Serving
#    • Usage: model.save('my_model')
#
# ⚠️ IMPORTANT NOTE:
#   When loading models, you may need to re-compile them
#   if optimizer state is not preserved!
#
# ✅ Model saving demonstrated!
